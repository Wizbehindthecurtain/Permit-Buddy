# %%
from pypdf import PdfReader, PdfWriter, generic
import pandas as pd
import os

# %%
from pypdf import PdfReader

template = 'Filled Electrical Form 24.pdf'
with open(template, 'rb') as file:
    reader = PdfReader(file)

    for page_num in range(len(reader.pages)):
        page = reader.pages[page_num]

        if '/Annots' in page:
            for field in page['/Annots']:
                obj = field.get_object()
                
                # Check if the object is a form field
                if '/T' in obj and '/FT' in obj:
                    field_name = obj['/T']
                    field_type = obj['/FT']
                    
                    print(f"Field Name: {field_name}")
                    print(f"Field Type: {field_type}")
                    
                    # Additional information depending on the type of field
                    if field_type == '/Tx':  # Text field
                        print(f"Field Value (/V): {obj.get('/V', None)}")
                        print(f"Field Default Value (/DV): {obj.get('/DV', None)}")
                        print(f"Field Flags (/Ff): {obj.get('/Ff', None)}")
                        
                        # Look for visibility-related information in the /DA string
                        da_string = obj.get('/DA', None)
                        if da_string:
                            print(f"Field Default Appearance (/DA): {da_string}")
                            # Extract additional information from the /DA string if needed
                        
                    elif field_type == '/Btn':  # Button field
                        print(f"Field Value (/V): {obj.get('/V', None)}")
                        print(f"Field Flags (/Ff): {obj.get('/Ff', None)}")
                        print(f"Field Default Appearance (/DA): {obj.get('/DA', None)}")
                        print(f"Field Appearance State (/AS): {obj.get('/AS', None)}")
                    
                    print("-" * 30)  # Separator between fields

# Note: This is a basic example, and you may need to adapt it based on your specific PDF structure and the details you want to extract.
# Out:
# Field Name: Application Number
# Field Type: /Tx
# Field Value (/V): None
# Field Default Value (/DV): None
# Field Flags (/Ff): None
# ------------------------------
# Field Name: Job Address
# Field Type: /Tx
# Field Value (/V): A25
# Field Default Value (/DV): None
# Field Flags (/Ff): 0
# ------------------------------
# Field Name: Unit
# Field Type: /Tx
# Field Value (/V): None
# Field Default Value (/DV): None
# Field Flags (/Ff): None
# ------------------------------
# Field Name: City
# Field Type: /Tx
# Field Value (/V): B25
# Field Default Value (/DV): None
# Field Flags (/Ff): 0
# ------------------------------
# Field Name: Tax Folio No
# Field Type: /Tx
# Field Value (/V): C25
# Field Default Value (/DV): None
# Field Flags (/Ff): 0
# ------------------------------
# Field Name: BFE
# Field Type: /Tx
# Field Value (/V): None
# Field Default Value (/DV): None
# Field Flags (/Ff): None
# ------------------------------
# Field Name: Floor Area
# Field Type: /Tx
# Field Value (/V): None
# Field Default Value (/DV): None
# Field Flags (/Ff): None
# ------------------------------
# Field Name: Job Value
# Field Type: /Tx
# Field Value (/V): D25
# Field Default Value (/DV): None
# Field Flags (/Ff): 0
# ------------------------------
# Field Name: Building Use
# Field Type: /Tx
# Field Value (/V): Residential
# Field Default Value (/DV): None
# Field Flags (/Ff): 0
# ------------------------------
# Field Name: Present Use
# Field Type: /Tx
# Field Value (/V): Residential
# Field Default Value (/DV): None
# Field Flags (/Ff): 0
# ------------------------------
# Field Name: Proposed Used
# Field Type: /Tx
# Field Value (/V): None
# Field Default Value (/DV): None
# Field Flags (/Ff): 2
# ------------------------------
# Field Name: Description of Work
# Field Type: /Tx
# Field Value (/V): Solar System Roof Mount and Interconnection
# Field Default Value (/DV): None
# Field Flags (/Ff): 0
# ------------------------------
# Field Name: Other_2
# Field Type: /Tx
# Field Value (/V): None
# Field Default Value (/DV): None
# Field Flags (/Ff): None
# ------------------------------
# Field Name: Legal Description
# Field Type: /Tx
# Field Value (/V): E25
# Field Default Value (/DV): None
# Field Flags (/Ff): 0
# ------------------------------
# Field Name: Property Owner
# Field Type: /Tx
# Field Value (/V): F25
# Field Default Value (/DV): None
# Field Flags (/Ff): 0
# ------------------------------
# Field Name: Phone
# Field Type: /Tx
# Field Value (/V): G25
# Field Default Value (/DV): None
# Field Flags (/Ff): 0
# ------------------------------
# Field Name: Email
# Field Type: /Tx
# Field Value (/V): H25
# Field Default Value (/DV): None
# Field Flags (/Ff): 0
# ------------------------------
# Field Name: Owners Address
# Field Type: /Tx
# Field Value (/V): I25
# Field Default Value (/DV): None
# Field Flags (/Ff): 0
# ------------------------------
# Field Name: City_2
# Field Type: /Tx
# Field Value (/V): None
# Field Default Value (/DV): None
# Field Flags (/Ff): 2
# ------------------------------
# Field Name: State
# Field Type: /Tx
# Field Value (/V): K25
# Field Default Value (/DV): None
# Field Flags (/Ff): 0
# ------------------------------
# Field Name: Zip
# Field Type: /Tx
# Field Value (/V): L25
# Field Default Value (/DV): None
# Field Flags (/Ff): 0
# ------------------------------
# Field Name: Contracting Co
# Field Type: /Tx
# Field Value (/V): MES Electric
# Field Default Value (/DV): None
# Field Flags (/Ff): 0
# ------------------------------
# Field Name: Phone_2
# Field Type: /Tx
# Field Value (/V): (571) 422-0970
# Field Default Value (/DV): None
# Field Flags (/Ff): 0
# ------------------------------
# Field Name: Email_2
# Field Type: /Tx
# Field Value (/V): jackson.mcinerney@smartroofinc.com
# Field Default Value (/DV): None
# Field Flags (/Ff): 0
# ------------------------------
# Field Name: Company Address
# Field Type: /Tx
# Field Value (/V): 2083 Guadelupe Dr
# Field Default Value (/DV): None
# Field Flags (/Ff): 0
# ------------------------------
# Field Name: City_3
# Field Type: /Tx
# Field Value (/V): Wellington
# Field Default Value (/DV): None
# Field Flags (/Ff): 0
# ------------------------------
# Field Name: State_2
# Field Type: /Tx
# Field Value (/V): FL
# Field Default Value (/DV): None
# Field Flags (/Ff): 0
# ------------------------------
# Field Name: Zip_2
# Field Type: /Tx
# Field Value (/V): 33414
# Field Default Value (/DV): None
# Field Flags (/Ff): 0
# ------------------------------
# Field Name: Qualifiers Name
# Field Type: /Tx
# Field Value (/V): Mark Spoor
# Field Default Value (/DV): None
# Field Flags (/Ff): 0
# ------------------------------
# Field Name: License Number
# Field Type: /Tx
# Field Value (/V): EC13001707
# Field Default Value (/DV): None
# Field Flags (/Ff): 0
# ------------------------------
# Field Name: ArchitectEngineers Name
# Field Type: /Tx
# Field Value (/V): None
# Field Default Value (/DV): None
# Field Flags (/Ff): None
# ------------------------------
# Field Name: Phone_3
# Field Type: /Tx
# Field Value (/V): None
# Field Default Value (/DV): None
# Field Flags (/Ff): None
# ------------------------------
# Field Name: Email_3
# Field Type: /Tx
# Field Value (/V): None
# Field Default Value (/DV): None
# Field Flags (/Ff): None
# ------------------------------
# Field Name: ArchitectEngineers Address
# Field Type: /Tx
# Field Value (/V): None
# Field Default Value (/DV): None
# Field Flags (/Ff): None
# ------------------------------
# Field Name: City_4
# Field Type: /Tx
# Field Value (/V): None
# Field Default Value (/DV): None
# Field Flags (/Ff): None
# ------------------------------
# Field Name: State_3
# Field Type: /Tx
# Field Value (/V): None
# Field Default Value (/DV): None
# Field Flags (/Ff): None
# ------------------------------
# Field Name: Zip_3
# Field Type: /Tx
# Field Value (/V): None
# Field Default Value (/DV): None
# Field Flags (/Ff): None
# ------------------------------
# Field Name: Bonding Company
# Field Type: /Tx
# Field Value (/V): None
# Field Default Value (/DV): None
# Field Flags (/Ff): None
# ------------------------------
# Field Name: Bonding Companys Address
# Field Type: /Tx
# Field Value (/V): None
# Field Default Value (/DV): None
# Field Flags (/Ff): None
# ------------------------------
# Field Name: City_5
# Field Type: /Tx
# Field Value (/V): None
# Field Default Value (/DV): None
# Field Flags (/Ff): None
# ------------------------------
# Field Name: State_4
# Field Type: /Tx
# Field Value (/V): None
# Field Default Value (/DV): None
# Field Flags (/Ff): None
# ------------------------------
# Field Name: Zip_4
# Field Type: /Tx
# Field Value (/V): None
# Field Default Value (/DV): None
# Field Flags (/Ff): None
# ------------------------------
# Field Name: Fee Simple Titleholders Name If other than the owner
# Field Type: /Tx
# Field Value (/V): None
# Field Default Value (/DV): None
# Field Flags (/Ff): None
# ------------------------------
# Field Name: If other than the owner
# Field Type: /Tx
# Field Value (/V): None
# Field Default Value (/DV): None
# Field Flags (/Ff): None
# ------------------------------
# Field Name: City_6
# Field Type: /Tx
# Field Value (/V): None
# Field Default Value (/DV): None
# Field Flags (/Ff): None
# ------------------------------
# Field Name: State_5
# Field Type: /Tx
# Field Value (/V): None
# Field Default Value (/DV): None
# Field Flags (/Ff): None
# ------------------------------
# Field Name: Zip_5
# Field Type: /Tx
# Field Value (/V): None
# Field Default Value (/DV): None
# Field Flags (/Ff): None
# ------------------------------
# Field Name: Mortgage Lenders Name
# Field Type: /Tx
# Field Value (/V): None
# Field Default Value (/DV): None
# Field Flags (/Ff): None
# ------------------------------
# Field Name: Mortgage Lenders Name_2
# Field Type: /Tx
# Field Value (/V): None
# Field Default Value (/DV): None
# Field Flags (/Ff): None
# ------------------------------
# Field Name: City_7
# Field Type: /Tx
# Field Value (/V): None
# Field Default Value (/DV): None
# Field Flags (/Ff): None
# ------------------------------
# Field Name: State_6
# Field Type: /Tx
# Field Value (/V): None
# Field Default Value (/DV): None
# Field Flags (/Ff): None
# ------------------------------
# Field Name: Zip_6
# Field Type: /Tx
# Field Value (/V): None
# Field Default Value (/DV): None
# Field Flags (/Ff): None
# ------------------------------
# Field Name: 1ATTACHMENTCheck Box
# Field Type: /Btn
# Field Value (/V): None
# Field Flags (/Ff): None
# Field Default Appearance (/DA): None
# Field Appearance State (/AS): /Off
# ------------------------------
# Field Name: TRADE-BUILDINGCheck Box
# Field Type: /Btn
# Field Value (/V): None
# Field Flags (/Ff): 2
# Field Default Appearance (/DA): None
# Field Appearance State (/AS): /Off
# ------------------------------
# Field Name: TRADE-ELECTRICALCheck Box
# Field Type: /Btn
# Field Value (/V): Yes
# Field Flags (/Ff): 2
# Field Default Appearance (/DA): None
# Field Appearance State (/AS): Yes
# ------------------------------
# Field Name: TRADE-PLUMBINGCheck Box
# Field Type: /Btn
# Field Value (/V): None
# Field Flags (/Ff): 2
# Field Default Appearance (/DA): None
# Field Appearance State (/AS): /Off
# ------------------------------
# Field Name: TRADE-MECHANICALCheck Box
# Field Type: /Btn
# Field Value (/V): None
# Field Flags (/Ff): 2
# Field Default Appearance (/DA): None
# Field Appearance State (/AS): /Off
# ------------------------------
# Field Name: TRADE-OTHERCheck Box
# Field Type: /Btn
# Field Value (/V): None
# Field Flags (/Ff): 2
# Field Default Appearance (/DA): None
# Field Appearance State (/AS): /Off
# ------------------------------
# Field Name: WORK-NEWCheck Box
# Field Type: /Btn
# Field Value (/V): None
# Field Flags (/Ff): 2
# Field Default Appearance (/DA): None
# Field Appearance State (/AS): /Off
# ------------------------------
# Field Name: WORK-ADDITIONCheck Box
# Field Type: /Btn
# Field Value (/V): None
# Field Flags (/Ff): 2
# Field Default Appearance (/DA): None
# Field Appearance State (/AS): /Off
# ------------------------------
# Field Name: WORK-REPAIRCheck Box
# Field Type: /Btn
# Field Value (/V): None
# Field Flags (/Ff): 2
# Field Default Appearance (/DA): None
# Field Appearance State (/AS): /Off
# ------------------------------
# Field Name: WORK-ALTERATIONCheck Box
# Field Type: /Btn
# Field Value (/V): None
# Field Flags (/Ff): 2
# Field Default Appearance (/DA): None
# Field Appearance State (/AS): /Off
# ------------------------------
# Field Name: WORK-DEMOLITIONCheck Box
# Field Type: /Btn
# Field Value (/V): None
# Field Flags (/Ff): 2
# Field Default Appearance (/DA): None
# Field Appearance State (/AS): /Off
# ------------------------------
# Field Name: WORK-REVISIONCheck Box
# Field Type: /Btn
# Field Value (/V): None
# Field Flags (/Ff): 2
# Field Default Appearance (/DA): None
# Field Appearance State (/AS): /Off
# ------------------------------
# Field Name: WORK-OTHERCheck Box
# Field Type: /Btn
# Field Value (/V): None
# Field Flags (/Ff): 2
# Field Default Appearance (/DA): None
# Field Appearance State (/AS): /Off
# ------------------------------
# Field Name: 2OWNERBUILDERCheck Box
# Field Type: /Btn
# Field Value (/V): None
# Field Flags (/Ff): None
# Field Default Appearance (/DA): None
# Field Appearance State (/AS): /Off
# ------------------------------
# Field Name: OTHERDropdown
# Field Type: /Ch
# ------------------------------
# Field Name: FLOOZNDropdown
# Field Type: /Ch
# ------------------------------
# Field Name: Dropdown4
# Field Type: /Ch
# ------------------------------
# Field Name: Dropdown5
# Field Type: /Ch
# ------------------------------
# Field Name: Application Date_af_date
# Field Type: /Tx
# Field Value (/V): None
# Field Default Value (/DV): None
# Field Flags (/Ff): None
# ------------------------------
# Field Name: APPROVED BY
# Field Type: /Tx
# Field Value (/V): None
# Field Default Value (/DV): None
# Field Flags (/Ff): None
# ------------------------------
# Field Name: Issue Date
# Field Type: /Tx
# Field Value (/V): None
# Field Default Value (/DV): None
# Field Flags (/Ff): None
# ------------------------------
# Field Name: Code in Effect
# Field Type: /Tx
# Field Value (/V): None
# Field Default Value (/DV): None
# Field Flags (/Ff): None
# ------------------------------
# Field Name: X
# Field Type: /Tx
# Field Value (/V): None
# Field Default Value (/DV): None
# Field Flags (/Ff): None
# ------------------------------
# Field Name: X_2
# Field Type: /Tx
# Field Value (/V): None
# Field Default Value (/DV): None
# Field Flags (/Ff): None
# ------------------------------
# Field Name: COUNTY OF
# Field Type: /Tx
# Field Value (/V): None
# Field Default Value (/DV): None
# Field Flags (/Ff): None
# ------------------------------
# Field Name: COUNTY OF_2
# Field Type: /Tx
# Field Value (/V): None
# Field Default Value (/DV): None
# Field Flags (/Ff): None
# ------------------------------
# Field Name: NOTARY DATE 1
# Field Type: /Tx
# Field Value (/V): None
# Field Default Value (/DV): None
# Field Flags (/Ff): None
# ------------------------------
# Field Name: NOTARY DATE 2
# Field Type: /Tx
# Field Value (/V): None
# Field Default Value (/DV): None
# Field Flags (/Ff): None
# ------------------------------
# Field Name: physical presence or
# Field Type: /Tx
# Field Value (/V): None
# Field Default Value (/DV): None
# Field Flags (/Ff): None
# ------------------------------
# Field Name: physical presence or_2
# Field Type: /Tx
# Field Value (/V): None
# Field Default Value (/DV): None
# Field Flags (/Ff): None
# ------------------------------
# Field Name: 20
# Field Type: /Tx
# Field Value (/V): None
# Field Default Value (/DV): None
# Field Flags (/Ff): None
# ------------------------------
# Field Name: 20_2
# Field Type: /Tx
# Field Value (/V): None
# Field Default Value (/DV): None
# Field Flags (/Ff): None
# ------------------------------
# Field Name: TypePrint Property Owner or Agent Name
# Field Type: /Tx
# Field Value (/V): None
# Field Default Value (/DV): None
# Field Flags (/Ff): None
# ------------------------------
# Field Name: TypePrint Property Owner or Agent Name_2
# Field Type: /Tx
# Field Value (/V): Mark Spoor
# Field Default Value (/DV): None
# Field Flags (/Ff): 0
# ------------------------------
# Field Name: NOTARYS SIGNATURE as to Owner or Agents Signature
# Field Type: /Sig
# ------------------------------
# Field Name: NOTARYS SIGNATURE as to Qualifiers Signature
# Field Type: /Sig
# ------------------------------
# Field Name: Notary Name
# Field Type: /Tx
# Field Value (/V): None
# Field Default Value (/DV): None
# Field Flags (/Ff): None
# ------------------------------
# Field Name: Notary Name_2
# Field Type: /Tx
# Field Value (/V): Jackson McInerney
# Field Default Value (/DV): None
# Field Flags (/Ff): 0
# ------------------------------
# Field Name: Personally Known
# Field Type: /Tx
# Field Value (/V): None
# Field Default Value (/DV): None
# Field Flags (/Ff): None
# ------------------------------
# Field Name: Produced Identification
# Field Type: /Tx
# Field Value (/V): None
# Field Default Value (/DV): None
# Field Flags (/Ff): None
# ------------------------------
# Field Name: Personally Known_2
# Field Type: /Tx
# Field Value (/V): None
# Field Default Value (/DV): None
# Field Flags (/Ff): None
# ------------------------------
# Field Name: Produced Identification_2
# Field Type: /Tx
# Field Value (/V): None
# Field Default Value (/DV): None
# Field Flags (/Ff): None
# ------------------------------
# Field Name: Type of Identification Produced
# Field Type: /Tx
# Field Value (/V): None
# Field Default Value (/DV): None
# Field Flags (/Ff): None
# ------------------------------
# Field Name: Type of Identification Produced_2
# Field Type: /Tx
# Field Value (/V): None
# Field Default Value (/DV): None
# Field Flags (/Ff): None
# ------------------------------
# Field Name: PHYSICAL1Check Box
# Field Type: /Btn
# Field Value (/V): None
# Field Flags (/Ff): None
# Field Default Appearance (/DA): None
# Field Appearance State (/AS): /Off
# ------------------------------
# Field Name: ONLINE1Check Box
# Field Type: /Btn
# Field Value (/V): None
# Field Flags (/Ff): None
# Field Default Appearance (/DA): None
# Field Appearance State (/AS): /Off
# ------------------------------
# Field Name: PHYSICAL2Check Box
# Field Type: /Btn
# Field Value (/V): None
# Field Flags (/Ff): None
# Field Default Appearance (/DA): None
# Field Appearance State (/AS): /Off
# ------------------------------
# Field Name: ONLINE2Check Box
# Field Type: /Btn
# Field Value (/V): None
# Field Flags (/Ff): None
# Field Default Appearance (/DA): None
# Field Appearance State (/AS): /Off
# ------------------------------

# %%
template = 'Filled Electrical Form 24.pdf'
with open(template, 'rb') as file:
    reader = PdfReader(file)

    for page_num in range(len(reader.pages)):
        page = reader.pages[page_num]

        if '/Annots' in page:
            for field in page['/Annots']:
                obj = field.get_object()
                
                # Check if the object is a form field
                if '/T' in obj and '/FT' in obj:
                    field_name = obj['/T']
                    field_type = obj['/FT']
                    
                    print(f"Field Name: {field_name}")
                    print(f"Field Type: {field_type}")
                    
                    # Additional information depending on the type of field
                    if field_type == '/Tx':  # Text field
                        print(f"Field Value (/V): {obj.get('/V', None)}")
                        print(f"Field Default Value (/DV): {obj.get('/DV', None)}")
                        print(f"Field Flags (/Ff): {obj.get('/Ff', None)}")
                        
                        # Look for visibility-related information in the /DA string
                        da_string = obj.get('/DA', None)
                        if da_string:
                            print(f"Field Default Appearance (/DA): {da_string}")
                            # Extract additional information from the /DA string if needed
                        
                    elif field_type == '/Btn':  # Button field
                        print(f"Field Value (/V): {obj.get('/V', None)}")
                        print(f"Field Flags (/Ff): {obj.get('/Ff', None)}")
                        print(f"Field Default Appearance (/DA): {obj.get('/DA', None)}")
                        print(f"Field Appearance State (/AS): {obj.get('/AS', None)}")
                    
                    print("-" * 30)  # Separator between fields

# Note: This is a basic example, and you may need to adapt it based on your specific PDF structure and the details you want to extract.
# Out:
# Field Name: Application Number
# Field Type: /Tx
# Field Value (/V): None
# Field Default Value (/DV): None
# Field Flags (/Ff): None
# ------------------------------
# Field Name: Job Address
# Field Type: /Tx
# Field Value (/V): A25
# Field Default Value (/DV): None
# Field Flags (/Ff): 0
# ------------------------------
# Field Name: Unit
# Field Type: /Tx
# Field Value (/V): None
# Field Default Value (/DV): None
# Field Flags (/Ff): None
# ------------------------------
# Field Name: City
# Field Type: /Tx
# Field Value (/V): B25
# Field Default Value (/DV): None
# Field Flags (/Ff): 0
# ------------------------------
# Field Name: Tax Folio No
# Field Type: /Tx
# Field Value (/V): C25
# Field Default Value (/DV): None
# Field Flags (/Ff): 0
# ------------------------------
# Field Name: BFE
# Field Type: /Tx
# Field Value (/V): None
# Field Default Value (/DV): None
# Field Flags (/Ff): None
# ------------------------------
# Field Name: Floor Area
# Field Type: /Tx
# Field Value (/V): None
# Field Default Value (/DV): None
# Field Flags (/Ff): None
# ------------------------------
# Field Name: Job Value
# Field Type: /Tx
# Field Value (/V): D25
# Field Default Value (/DV): None
# Field Flags (/Ff): 0
# ------------------------------
# Field Name: Building Use
# Field Type: /Tx
# Field Value (/V): Residential
# Field Default Value (/DV): None
# Field Flags (/Ff): 0
# ------------------------------
# Field Name: Present Use
# Field Type: /Tx
# Field Value (/V): Residential
# Field Default Value (/DV): None
# Field Flags (/Ff): 0
# ------------------------------
# Field Name: Proposed Used
# Field Type: /Tx
# Field Value (/V): None
# Field Default Value (/DV): None
# Field Flags (/Ff): 2
# ------------------------------
# Field Name: Description of Work
# Field Type: /Tx
# Field Value (/V): Solar System Roof Mount and Interconnection
# Field Default Value (/DV): None
# Field Flags (/Ff): 0
# ------------------------------
# Field Name: Other_2
# Field Type: /Tx
# Field Value (/V): None
# Field Default Value (/DV): None
# Field Flags (/Ff): None
# ------------------------------
# Field Name: Legal Description
# Field Type: /Tx
# Field Value (/V): E25
# Field Default Value (/DV): None
# Field Flags (/Ff): 0
# ------------------------------
# Field Name: Property Owner
# Field Type: /Tx
# Field Value (/V): F25
# Field Default Value (/DV): None
# Field Flags (/Ff): 0
# ------------------------------
# Field Name: Phone
# Field Type: /Tx
# Field Value (/V): G25
# Field Default Value (/DV): None
# Field Flags (/Ff): 0
# ------------------------------
# Field Name: Email
# Field Type: /Tx
# Field Value (/V): H25
# Field Default Value (/DV): None
# Field Flags (/Ff): 0
# ------------------------------
# Field Name: Owners Address
# Field Type: /Tx
# Field Value (/V): I25
# Field Default Value (/DV): None
# Field Flags (/Ff): 0
# ------------------------------
# Field Name: City_2
# Field Type: /Tx
# Field Value (/V): None
# Field Default Value (/DV): None
# Field Flags (/Ff): 2
# ------------------------------
# Field Name: State
# Field Type: /Tx
# Field Value (/V): K25
# Field Default Value (/DV): None
# Field Flags (/Ff): 0
# ------------------------------
# Field Name: Zip
# Field Type: /Tx
# Field Value (/V): L25
# Field Default Value (/DV): None
# Field Flags (/Ff): 0
# ------------------------------
# Field Name: Contracting Co
# Field Type: /Tx
# Field Value (/V): MES Electric
# Field Default Value (/DV): None
# Field Flags (/Ff): 0
# ------------------------------
# Field Name: Phone_2
# Field Type: /Tx
# Field Value (/V): (571) 422-0970
# Field Default Value (/DV): None
# Field Flags (/Ff): 0
# ------------------------------
# Field Name: Email_2
# Field Type: /Tx
# Field Value (/V): jackson.mcinerney@smartroofinc.com
# Field Default Value (/DV): None
# Field Flags (/Ff): 0
# ------------------------------
# Field Name: Company Address
# Field Type: /Tx
# Field Value (/V): 2083 Guadelupe Dr
# Field Default Value (/DV): None
# Field Flags (/Ff): 0
# ------------------------------
# Field Name: City_3
# Field Type: /Tx
# Field Value (/V): Wellington
# Field Default Value (/DV): None
# Field Flags (/Ff): 0
# ------------------------------
# Field Name: State_2
# Field Type: /Tx
# Field Value (/V): FL
# Field Default Value (/DV): None
# Field Flags (/Ff): 0
# ------------------------------
# Field Name: Zip_2
# Field Type: /Tx
# Field Value (/V): 33414
# Field Default Value (/DV): None
# Field Flags (/Ff): 0
# ------------------------------
# Field Name: Qualifiers Name
# Field Type: /Tx
# Field Value (/V): Mark Spoor
# Field Default Value (/DV): None
# Field Flags (/Ff): 0
# ------------------------------
# Field Name: License Number
# Field Type: /Tx
# Field Value (/V): EC13001707
# Field Default Value (/DV): None
# Field Flags (/Ff): 0
# ------------------------------
# Field Name: ArchitectEngineers Name
# Field Type: /Tx
# Field Value (/V): None
# Field Default Value (/DV): None
# Field Flags (/Ff): None
# ------------------------------
# Field Name: Phone_3
# Field Type: /Tx
# Field Value (/V): None
# Field Default Value (/DV): None
# Field Flags (/Ff): None
# ------------------------------
# Field Name: Email_3
# Field Type: /Tx
# Field Value (/V): None
# Field Default Value (/DV): None
# Field Flags (/Ff): None
# ------------------------------
# Field Name: ArchitectEngineers Address
# Field Type: /Tx
# Field Value (/V): None
# Field Default Value (/DV): None
# Field Flags (/Ff): None
# ------------------------------
# Field Name: City_4
# Field Type: /Tx
# Field Value (/V): None
# Field Default Value (/DV): None
# Field Flags (/Ff): None
# ------------------------------
# Field Name: State_3
# Field Type: /Tx
# Field Value (/V): None
# Field Default Value (/DV): None
# Field Flags (/Ff): None
# ------------------------------
# Field Name: Zip_3
# Field Type: /Tx
# Field Value (/V): None
# Field Default Value (/DV): None
# Field Flags (/Ff): None
# ------------------------------
# Field Name: Bonding Company
# Field Type: /Tx
# Field Value (/V): None
# Field Default Value (/DV): None
# Field Flags (/Ff): None
# ------------------------------
# Field Name: Bonding Companys Address
# Field Type: /Tx
# Field Value (/V): None
# Field Default Value (/DV): None
# Field Flags (/Ff): None
# ------------------------------
# Field Name: City_5
# Field Type: /Tx
# Field Value (/V): None
# Field Default Value (/DV): None
# Field Flags (/Ff): None
# ------------------------------
# Field Name: State_4
# Field Type: /Tx
# Field Value (/V): None
# Field Default Value (/DV): None
# Field Flags (/Ff): None
# ------------------------------
# Field Name: Zip_4
# Field Type: /Tx
# Field Value (/V): None
# Field Default Value (/DV): None
# Field Flags (/Ff): None
# ------------------------------
# Field Name: Fee Simple Titleholders Name If other than the owner
# Field Type: /Tx
# Field Value (/V): None
# Field Default Value (/DV): None
# Field Flags (/Ff): None
# ------------------------------
# Field Name: If other than the owner
# Field Type: /Tx
# Field Value (/V): None
# Field Default Value (/DV): None
# Field Flags (/Ff): None
# ------------------------------
# Field Name: City_6
# Field Type: /Tx
# Field Value (/V): None
# Field Default Value (/DV): None
# Field Flags (/Ff): None
# ------------------------------
# Field Name: State_5
# Field Type: /Tx
# Field Value (/V): None
# Field Default Value (/DV): None
# Field Flags (/Ff): None
# ------------------------------
# Field Name: Zip_5
# Field Type: /Tx
# Field Value (/V): None
# Field Default Value (/DV): None
# Field Flags (/Ff): None
# ------------------------------
# Field Name: Mortgage Lenders Name
# Field Type: /Tx
# Field Value (/V): None
# Field Default Value (/DV): None
# Field Flags (/Ff): None
# ------------------------------
# Field Name: Mortgage Lenders Name_2
# Field Type: /Tx
# Field Value (/V): None
# Field Default Value (/DV): None
# Field Flags (/Ff): None
# ------------------------------
# Field Name: City_7
# Field Type: /Tx
# Field Value (/V): None
# Field Default Value (/DV): None
# Field Flags (/Ff): None
# ------------------------------
# Field Name: State_6
# Field Type: /Tx
# Field Value (/V): None
# Field Default Value (/DV): None
# Field Flags (/Ff): None
# ------------------------------
# Field Name: Zip_6
# Field Type: /Tx
# Field Value (/V): None
# Field Default Value (/DV): None
# Field Flags (/Ff): None
# ------------------------------
# Field Name: 1ATTACHMENTCheck Box
# Field Type: /Btn
# Field Value (/V): None
# Field Flags (/Ff): None
# Field Default Appearance (/DA): None
# Field Appearance State (/AS): /Off
# ------------------------------
# Field Name: TRADE-BUILDINGCheck Box
# Field Type: /Btn
# Field Value (/V): None
# Field Flags (/Ff): 2
# Field Default Appearance (/DA): None
# Field Appearance State (/AS): /Off
# ------------------------------
# Field Name: TRADE-ELECTRICALCheck Box
# Field Type: /Btn
# Field Value (/V): Yes
# Field Flags (/Ff): 2
# Field Default Appearance (/DA): None
# Field Appearance State (/AS): Yes
# ------------------------------
# Field Name: TRADE-PLUMBINGCheck Box
# Field Type: /Btn
# Field Value (/V): None
# Field Flags (/Ff): 2
# Field Default Appearance (/DA): None
# Field Appearance State (/AS): /Off
# ------------------------------
# Field Name: TRADE-MECHANICALCheck Box
# Field Type: /Btn
# Field Value (/V): None
# Field Flags (/Ff): 2
# Field Default Appearance (/DA): None
# Field Appearance State (/AS): /Off
# ------------------------------
# Field Name: TRADE-OTHERCheck Box
# Field Type: /Btn
# Field Value (/V): None
# Field Flags (/Ff): 2
# Field Default Appearance (/DA): None
# Field Appearance State (/AS): /Off
# ------------------------------
# Field Name: WORK-NEWCheck Box
# Field Type: /Btn
# Field Value (/V): None
# Field Flags (/Ff): 2
# Field Default Appearance (/DA): None
# Field Appearance State (/AS): /Off
# ------------------------------
# Field Name: WORK-ADDITIONCheck Box
# Field Type: /Btn
# Field Value (/V): None
# Field Flags (/Ff): 2
# Field Default Appearance (/DA): None
# Field Appearance State (/AS): /Off
# ------------------------------
# Field Name: WORK-REPAIRCheck Box
# Field Type: /Btn
# Field Value (/V): None
# Field Flags (/Ff): 2
# Field Default Appearance (/DA): None
# Field Appearance State (/AS): /Off
# ------------------------------
# Field Name: WORK-ALTERATIONCheck Box
# Field Type: /Btn
# Field Value (/V): None
# Field Flags (/Ff): 2
# Field Default Appearance (/DA): None
# Field Appearance State (/AS): /Off
# ------------------------------
# Field Name: WORK-DEMOLITIONCheck Box
# Field Type: /Btn
# Field Value (/V): None
# Field Flags (/Ff): 2
# Field Default Appearance (/DA): None
# Field Appearance State (/AS): /Off
# ------------------------------
# Field Name: WORK-REVISIONCheck Box
# Field Type: /Btn
# Field Value (/V): None
# Field Flags (/Ff): 2
# Field Default Appearance (/DA): None
# Field Appearance State (/AS): /Off
# ------------------------------
# Field Name: WORK-OTHERCheck Box
# Field Type: /Btn
# Field Value (/V): None
# Field Flags (/Ff): 2
# Field Default Appearance (/DA): None
# Field Appearance State (/AS): /Off
# ------------------------------
# Field Name: 2OWNERBUILDERCheck Box
# Field Type: /Btn
# Field Value (/V): None
# Field Flags (/Ff): None
# Field Default Appearance (/DA): None
# Field Appearance State (/AS): /Off
# ------------------------------
# Field Name: OTHERDropdown
# Field Type: /Ch
# ------------------------------
# Field Name: FLOOZNDropdown
# Field Type: /Ch
# ------------------------------
# Field Name: Dropdown4
# Field Type: /Ch
# ------------------------------
# Field Name: Dropdown5
# Field Type: /Ch
# ------------------------------
# Field Name: Application Date_af_date
# Field Type: /Tx
# Field Value (/V): None
# Field Default Value (/DV): None
# Field Flags (/Ff): None
# ------------------------------
# Field Name: APPROVED BY
# Field Type: /Tx
# Field Value (/V): None
# Field Default Value (/DV): None
# Field Flags (/Ff): None
# ------------------------------
# Field Name: Issue Date
# Field Type: /Tx
# Field Value (/V): None
# Field Default Value (/DV): None
# Field Flags (/Ff): None
# ------------------------------
# Field Name: Code in Effect
# Field Type: /Tx
# Field Value (/V): None
# Field Default Value (/DV): None
# Field Flags (/Ff): None
# ------------------------------
# Field Name: X
# Field Type: /Tx
# Field Value (/V): None
# Field Default Value (/DV): None
# Field Flags (/Ff): None
# ------------------------------
# Field Name: X_2
# Field Type: /Tx
# Field Value (/V): None
# Field Default Value (/DV): None
# Field Flags (/Ff): None
# ------------------------------
# Field Name: COUNTY OF
# Field Type: /Tx
# Field Value (/V): None
# Field Default Value (/DV): None
# Field Flags (/Ff): None
# ------------------------------
# Field Name: COUNTY OF_2
# Field Type: /Tx
# Field Value (/V): None
# Field Default Value (/DV): None
# Field Flags (/Ff): None
# ------------------------------
# Field Name: NOTARY DATE 1
# Field Type: /Tx
# Field Value (/V): None
# Field Default Value (/DV): None
# Field Flags (/Ff): None
# ------------------------------
# Field Name: NOTARY DATE 2
# Field Type: /Tx
# Field Value (/V): None
# Field Default Value (/DV): None
# Field Flags (/Ff): None
# ------------------------------
# Field Name: physical presence or
# Field Type: /Tx
# Field Value (/V): None
# Field Default Value (/DV): None
# Field Flags (/Ff): None
# ------------------------------
# Field Name: physical presence or_2
# Field Type: /Tx
# Field Value (/V): None
# Field Default Value (/DV): None
# Field Flags (/Ff): None
# ------------------------------
# Field Name: 20
# Field Type: /Tx
# Field Value (/V): None
# Field Default Value (/DV): None
# Field Flags (/Ff): None
# ------------------------------
# Field Name: 20_2
# Field Type: /Tx
# Field Value (/V): None
# Field Default Value (/DV): None
# Field Flags (/Ff): None
# ------------------------------
# Field Name: TypePrint Property Owner or Agent Name
# Field Type: /Tx
# Field Value (/V): None
# Field Default Value (/DV): None
# Field Flags (/Ff): None
# ------------------------------
# Field Name: TypePrint Property Owner or Agent Name_2
# Field Type: /Tx
# Field Value (/V): Mark Spoor
# Field Default Value (/DV): None
# Field Flags (/Ff): 0
# ------------------------------
# Field Name: NOTARYS SIGNATURE as to Owner or Agents Signature
# Field Type: /Sig
# ------------------------------
# Field Name: NOTARYS SIGNATURE as to Qualifiers Signature
# Field Type: /Sig
# ------------------------------
# Field Name: Notary Name
# Field Type: /Tx
# Field Value (/V): None
# Field Default Value (/DV): None
# Field Flags (/Ff): None
# ------------------------------
# Field Name: Notary Name_2
# Field Type: /Tx
# Field Value (/V): Jackson McInerney
# Field Default Value (/DV): None
# Field Flags (/Ff): 0
# ------------------------------
# Field Name: Personally Known
# Field Type: /Tx
# Field Value (/V): None
# Field Default Value (/DV): None
# Field Flags (/Ff): None
# ------------------------------
# Field Name: Produced Identification
# Field Type: /Tx
# Field Value (/V): None
# Field Default Value (/DV): None
# Field Flags (/Ff): None
# ------------------------------
# Field Name: Personally Known_2
# Field Type: /Tx
# Field Value (/V): None
# Field Default Value (/DV): None
# Field Flags (/Ff): None
# ------------------------------
# Field Name: Produced Identification_2
# Field Type: /Tx
# Field Value (/V): None
# Field Default Value (/DV): None
# Field Flags (/Ff): None
# ------------------------------
# Field Name: Type of Identification Produced
# Field Type: /Tx
# Field Value (/V): None
# Field Default Value (/DV): None
# Field Flags (/Ff): None
# ------------------------------
# Field Name: Type of Identification Produced_2
# Field Type: /Tx
# Field Value (/V): None
# Field Default Value (/DV): None
# Field Flags (/Ff): None
# ------------------------------
# Field Name: PHYSICAL1Check Box
# Field Type: /Btn
# Field Value (/V): None
# Field Flags (/Ff): None
# Field Default Appearance (/DA): None
# Field Appearance State (/AS): /Off
# ------------------------------
# Field Name: ONLINE1Check Box
# Field Type: /Btn
# Field Value (/V): None
# Field Flags (/Ff): None
# Field Default Appearance (/DA): None
# Field Appearance State (/AS): /Off
# ------------------------------
# Field Name: PHYSICAL2Check Box
# Field Type: /Btn
# Field Value (/V): None
# Field Flags (/Ff): None
# Field Default Appearance (/DA): None
# Field Appearance State (/AS): /Off
# ------------------------------
# Field Name: ONLINE2Check Box
# Field Type: /Btn
# Field Value (/V): None
# Field Flags (/Ff): None
# Field Default Appearance (/DA): None
# Field Appearance State (/AS): /Off
# ------------------------------
